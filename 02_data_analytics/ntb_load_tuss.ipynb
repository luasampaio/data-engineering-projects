# %% [markdown]
# # Análise Exploratória
# - **Luciana Sampaio**
#
# - Criado em : 02.02.2025
# - Leitura e Tratativas de dados da ANS
# - dataset : CodigoTuss
# - site ANS : https://www.gov.br/ans/pt-br/assuntos/operadoras/avisos-para-operadoras/ans-atualiza-a-tabela-de-compatibilizacao-tuss-sip-2024

# %%
import pandas as pd
df = pd.read_csv('tuss.csv', sep=';' , encoding='utf-8', skiprows=2)

# %%
df.columns
# Out:
# Index(['Código Tab 22',
#        'Tabela 22 - Terminologia de Procedimentos e Eventos em Saúde (TUSS)',
#        'ROL ANS',
#        'ROL ANS Resolução Normativa nº 338/2013                                                                                                                                                                                                           ',
#        'SUBGRUPO', 'GRUPO', 'CAPÍTULO', 'OD', 'AMB', 'HCO',
#        ...
#        'Unnamed: 145', 'Unnamed: 146', 'Unnamed: 147', 'Unnamed: 148',
#        'Unnamed: 149', 'Unnamed: 150', 'Unnamed: 151', 'Unnamed: 152',
#        'Unnamed: 153', 'Unnamed: 154'],
#       dtype='object', length=155)

# %% [markdown]
# ### Eliminando colunas vazias

# %%
# Removendo colunas completamente vazias (todas as células são NaN)
df = df.dropna(axis=1, how="all")

# %%
df.head(5)
# Out:
#    Código Tab 22  \
# 0     10101012.0
# 1     10101012.0
# 2     10101012.0
# 3     10101020.0
# 4     10101039.0
#
#   Tabela 22 - Terminologia de Procedimentos e Eventos em Saúde (TUSS) ROL ANS  \
# 0  Consulta em consultório (no horário normal ou ...                      SIM
# 1  Consulta em consultório (no horário normal ou ...                      SIM
# 2  Consulta em consultório (no horário normal ou ...                      SIM
# 3                              Consulta em domicílio                      NÃO
# 4                         Consulta em pronto socorro                      SIM
#
#   ROL ANS Resolução Normativa nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                ---
# 4                                    CONSULTA MÉDICA
#
#                                             SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                NaN                   NaN
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                CAPÍTULO   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN

# %%
df.columns
# Out:
# Index(['Código Tab 22',
#        'Tabela 22 - Terminologia de Procedimentos e Eventos em Saúde (TUSS)',
#        'ROL ANS',
#        'ROL ANS Resolução Normativa nº 338/2013                                                                                                                                                                                                           ',
#        'SUBGRUPO', 'GRUPO', 'CAPÍTULO', 'OD', 'AMB', 'HCO', 'HSO', 'PAC',
#        'D.UT'],
#       dtype='object')

# %%
import pandas as pd

# Aplicando a remoção de espaços apenas nas colunas do tipo string
df[df.select_dtypes(include=["object"]).columns] = df.select_dtypes(include=["object"]).apply(lambda x: x.str.split().str.join(" "))

# %% [markdown]
# Renomeando Colunas

# %%
df = df.rename(columns={
    'Código Tab 22': 'codigo',
    'ROL ANS': 'rol_ans',
    'Tabela 22 - Terminologia de Procedimentos e Eventos em Saúde (TUSS)': 'procedimentos',
    'ROL ANS Resolução Normativa nº 338/2013': 'rol_ans_resolucao_338_2013',
    'SUBGRUPO': 'subgrupo',
    'GRUPO': 'grupo',
    'CAPÍTULO': 'capitulo'


})

# %%
df.head(5)
# Out:
#        codigo                                      procedimentos rol_ans  \
# 0  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3  10101020.0                              Consulta em domicílio     NÃO
# 4  10101039.0                         Consulta em pronto socorro     SIM
#
#   ROL ANS Resolução Normativa nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                ---
# 4                                    CONSULTA MÉDICA
#
#                                             subgrupo                 grupo  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                NaN                   NaN
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                capitulo   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN

# %%
df.columns = df.columns.str.upper()
df.head()
# Out:
#        CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3  10101020.0                              Consulta em domicílio     NÃO
# 4  10101039.0                         Consulta em pronto socorro     SIM
#
#   ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                ---
# 4                                    CONSULTA MÉDICA
#
#                                             SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                NaN                   NaN
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN

# %%
df.head()
# Out:
#        CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3  10101020.0                              Consulta em domicílio     NÃO
# 4  10101039.0                         Consulta em pronto socorro     SIM
#
#   ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                ---
# 4                                    CONSULTA MÉDICA
#
#                                             SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                NaN                   NaN
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN

# %%
df.columns
# Out:
# Index(['CODIGO', 'PROCEDIMENTOS', 'ROL_ANS',
#        'ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                           ',
#        'SUBGRUPO', 'GRUPO', 'CAPITULO', 'OD', 'AMB', 'HCO', 'HSO', 'PAC',
#        'D.UT'],
#       dtype='object')

# %%
df.head(100)
# Out:
#         CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0   10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1   10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2   10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3   10101020.0                              Consulta em domicílio     NÃO
# 4   10101039.0                         Consulta em pronto socorro     SIM
# ..         ...                                                ...     ...
# 95  20103387.0  Pacientes com doença isquêmica do coração, ate...     SIM
# 96  20103395.0  Pacientes com doença isquêmica do coração, ate...     SIM
# 97  20103409.0  Pacientes com doenças neuro-músculo-esquelétic...     SIM
# 98  20103417.0  Pacientes sem doença coronariana clinicamente ...     SIM
# 99  20103425.0                                 Paralisia cerebral     SIM
#
#    ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                     CONSULTA MÉDICA
# 1    ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2   CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                 ---
# 4                                     CONSULTA MÉDICA
# ..                                                ...
# 95           REEDUCAÇÃO E REABILITAÇÃO CARDIOVASCULAR
# 96           REEDUCAÇÃO E REABILITAÇÃO CARDIOVASCULAR
# 97  REEDUCAÇÃO E REABILITAÇÃO NEURO-MÚSCULO-ESQUEL...
# 98           REEDUCAÇÃO E REABILITAÇÃO CARDIOVASCULAR
# 99              REEDUCAÇÃO E REABILITAÇÃO NEUROLÓGICA
#
#                                              SUBGRUPO  \
# 0   CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 1   CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 2   CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# 3                                                 NaN
# 4   CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...
# ..                                                ...
# 95                                       REABILITAÇÃO
# 96                                       REABILITAÇÃO
# 97                                       REABILITAÇÃO
# 98                                       REABILITAÇÃO
# 99                                       REABILITAÇÃO
#
#                                                 GRUPO  \
# 0                                PROCEDIMENTOS GERAIS
# 1                                PROCEDIMENTOS GERAIS
# 2                                PROCEDIMENTOS GERAIS
# 3                                                 NaN
# 4                                PROCEDIMENTOS GERAIS
# ..                                                ...
# 95  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...
# 96  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...
# 97  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...
# 98  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...
# 99  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...
#
#                                              CAPITULO   OD  AMB  HCO  HSO  \
# 0                                PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN
# 1                                PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN
# 2                                PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN
# 3                                                 NaN  NaN  NaN  NaN  NaN
# 4                                PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN
# ..                                                ...  ...  ...  ...  ...
# 95  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...  NaN  AMB  HCO  HSO
# 96  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...  NaN  AMB  HCO  HSO
# 97  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...  NaN  AMB  HCO  HSO
# 98  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...  NaN  AMB  HCO  HSO
# 99  PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITA...  NaN  AMB  HCO  HSO
#
#     PAC D.UT
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# ..  ...  ...
# 95  NaN  NaN
# 96  NaN  NaN
# 97  NaN  NaN
# 98  NaN  NaN
# 99  NaN  NaN
#
# [100 rows x 13 columns]

# %%
df.size
# Out:
# 83278

# %%
df.describe()
# Out:
#              CODIGO
# count  6.400000e+03
# mean   3.837681e+07
# std    1.284181e+07
# min    1.010101e+07
# 25%    3.080108e+07
# 50%    4.030248e+07
# 75%    4.040419e+07
# max    8.700018e+07

# %%
print(df.dtypes)
# Out:
# CODIGO                                                                                                                                                                                                                                                float64
# PROCEDIMENTOS                                                                                                                                                                                                                                          object
# ROL_ANS                                                                                                                                                                                                                                                object
# ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                                object
# SUBGRUPO                                                                                                                                                                                                                                               object
# GRUPO                                                                                                                                                                                                                                                  object
# CAPITULO                                                                                                                                                                                                                                               object
# OD                                                                                                                                                                                                                                                     object
# AMB                                                                                                                                                                                                                                                    object
# HCO                                                                                                                                                                                                                                                    object
# HSO                                                                                                                                                                                                                                                    object
# PAC                                                                                                                                                                                                                                                    object
# D.UT                                                                                                                                                                                                                                                   object
# dtype: object

# %%
grouped_df = df.groupby('GRUPO').size().sort_values(ascending=False)
print(grouped_df)
# Out:
# GRUPO
# PROCEDIMENTOS LABORATORIAIS                            993
# SISTEMA MÚSCULO-ESQUELÉTICO E ARTICULAÇÕES             622
# MÉTODOS DIAGNÓSTICOS POR IMAGEM                        442
# CABEÇA E PESCOÇO                                       402
# SISTEMA DIGESTIVO E ANEXOS                             301
# PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITALARES    254
# GENÉTICA                                               242
# SISTEMA CÁRDIO-CIRCULATÓRIO                            221
# SISTEMA URINÁRIO                                       177
# OLHOS                                                  123
# SISTEMA GENITAL E REPRODUTOR FEMININO                  108
# MEDICINA TRANSFUSIONAL                                 105
# EXAMES ESPECÍFICOS                                     104
# ELETROFISIOLÓGICOS / MECÂNICOS E FUNCIONAIS            104
# ENDOSCÓPICOS                                           103
# SISTEMA RESPIRATÓRIO E MEDIASTINO                       93
# MEDICINA NUCLEAR                                        93
# PELE E TECIDO CELULAR SUBCUTÂNEO, MUCOSAS E ANEXOS      92
# SISTEMA NERVOSO - CENTRAL E PERIFÉRICO                  88
# NARIZ E SEIOS PARANASAIS                                80
# TRANSPLANTES DE ÓRGÃOS OU TECIDOS                       72
# PAREDE TORÁCICA                                         72
# SISTEMA GENITAL E REPRODUTOR MASCULINO                  68
# RADIOTERAPIA                                            64
# PROCEDIMENTOS GERAIS                                    63
# ANATOMIA PATOLÓGICA E CITOPATOLOGIA                     58
# ORELHA                                                  46
# OUTROS PROCEDIMENTOS INVASIVOS                          20
# dtype: int64

# %%
df.size
# Out:
# 83278

# %%
# Desse modo não fica tão elegante
df_duplicados = df.drop_duplicates()

# %%
df_duplicados.size
# Out:
# 83161

# %%
linhas, colunas = df.shape
print(f'Tamanho: {linhas} linhas e {colunas} colunas')
# Out:
# Tamanho: 6406 linhas e 13 colunas

# %% [markdown]
# ### Validando o volume de dados duplicados

# %%
#verificando os duplicados 
linhas, colunas = df_duplicados.shape
print(f'Tamanho: {linhas} linhas e {colunas} colunas')
# Out:
# Tamanho: 6397 linhas e 13 colunas

# %%
# Função para remover duplicados
def remove_duplicados(df):
    df.drop_duplicates(inplace=True)
    return df

# %%
df = remove_duplicados(df)

# %%
df.shape
# Out:
# (6397, 13)

# %%
df.head(3)
# Out:
#        CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
#
#   ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
#
#                                             SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN

# %%
df['GRUPO'].unique()
# Out:
# array(['PROCEDIMENTOS GERAIS', nan,
#        'PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITALARES',
#        'EXAMES ESPECÍFICOS', 'SISTEMA NERVOSO - CENTRAL E PERIFÉRICO',
#        'PELE E TECIDO CELULAR SUBCUTÂNEO, MUCOSAS E ANEXOS',
#        'MÉTODOS DIAGNÓSTICOS POR IMAGEM', 'ORELHA',
#        'SISTEMA GENITAL E REPRODUTOR MASCULINO',
#        'SISTEMA CÁRDIO-CIRCULATÓRIO', 'OLHOS',
#        'SISTEMA MÚSCULO-ESQUELÉTICO E ARTICULAÇÕES', 'CABEÇA E PESCOÇO',
#        'NARIZ E SEIOS PARANASAIS', 'PAREDE TORÁCICA',
#        'SISTEMA RESPIRATÓRIO E MEDIASTINO', 'SISTEMA DIGESTIVO E ANEXOS',
#        'SISTEMA GENITAL E REPRODUTOR FEMININO', 'SISTEMA URINÁRIO',
#        'ENDOSCÓPICOS', 'RADIOTERAPIA',
#        'TRANSPLANTES DE ÓRGÃOS OU TECIDOS',
#        'OUTROS PROCEDIMENTOS INVASIVOS',
#        'ELETROFISIOLÓGICOS / MECÂNICOS E FUNCIONAIS',
#        'PROCEDIMENTOS LABORATORIAIS', 'GENÉTICA',
#        'MEDICINA TRANSFUSIONAL', 'ANATOMIA PATOLÓGICA E CITOPATOLOGIA',
#        'MEDICINA NUCLEAR'], dtype=object)

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['PROCEDIMENTOS'].value_counts()
# Out:
# PROCEDIMENTOS
# Terapia antineoplásica oral para tratamento do câncer                                                                                                  72
# Cultura de fibroblastos (pele)                                                                                                                         27
# Pesquisa ou dosagem de um componente urinário                                                                                                          21
# Cultura de tecido para ensaio enzimático e/ou extração de DNA                                                                                          19
# Ensaios enzimáticos em células cultivadas para diagnóstico de EIM, incluindo preparo do material, dosagem de proteína e enzima de referência (cada)    14
#                                                                                                                                                        ..
# Herniorrafia com ressecção intestinal - estrangulada - por videolaparoscopia                                                                            1
# Teratoma sacro-coccígeo - exérese                                                                                                                       1
# Ressutura da parede abdominal (por deiscência total ou evisceração)                                                                                     1
# Ressecção de cisto ou fístula ou restos do ducto onfalomesentérico                                                                                      1
# Sedação medicamentosa ambulatorial em pacientes com necessidades especiais em odontologia                                                               1
# Name: count, Length: 5668, dtype: int64

# %%
df['GRUPO'].value_counts()
# Out:
# GRUPO
# PROCEDIMENTOS LABORATORIAIS                            991
# SISTEMA MÚSCULO-ESQUELÉTICO E ARTICULAÇÕES             622
# MÉTODOS DIAGNÓSTICOS POR IMAGEM                        441
# CABEÇA E PESCOÇO                                       402
# SISTEMA DIGESTIVO E ANEXOS                             301
# PROCEDIMENTOS CLÍNICOS AMBULATORIAIS E HOSPITALARES    254
# GENÉTICA                                               242
# SISTEMA CÁRDIO-CIRCULATÓRIO                            221
# SISTEMA URINÁRIO                                       177
# OLHOS                                                  123
# SISTEMA GENITAL E REPRODUTOR FEMININO                  108
# MEDICINA TRANSFUSIONAL                                 105
# EXAMES ESPECÍFICOS                                     104
# ELETROFISIOLÓGICOS / MECÂNICOS E FUNCIONAIS            104
# ENDOSCÓPICOS                                           103
# SISTEMA RESPIRATÓRIO E MEDIASTINO                       93
# MEDICINA NUCLEAR                                        93
# PELE E TECIDO CELULAR SUBCUTÂNEO, MUCOSAS E ANEXOS      92
# SISTEMA NERVOSO - CENTRAL E PERIFÉRICO                  88
# NARIZ E SEIOS PARANASAIS                                80
# PAREDE TORÁCICA                                         72
# TRANSPLANTES DE ÓRGÃOS OU TECIDOS                       72
# SISTEMA GENITAL E REPRODUTOR MASCULINO                  68
# RADIOTERAPIA                                            64
# PROCEDIMENTOS GERAIS                                    63
# ANATOMIA PATOLÓGICA E CITOPATOLOGIA                     58
# ORELHA                                                  46
# OUTROS PROCEDIMENTOS INVASIVOS                          20
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              CODIGO
# count  6.396000e+03
# mean   3.837551e+07
# std    1.284572e+07
# min    1.010101e+07
# 25%    3.080107e+07
# 50%    4.030246e+07
# 75%    4.040419e+07
# max    8.700018e+07

# %%
grupo = df[df['GRUPO'] == 'PROCEDIMENTOS LABORATORIAIS']

# %%
grupo = df.groupby("GRUPO").size().reset_index(name="Quantidade")

# Filtrando apenas "PROCEDIMENTOS LABORATORIAIS"
grupo_lab = grupo[grupo['GRUPO'] == 'PROCEDIMENTOS LABORATORIAIS']
print(grupo_lab)
# Out:
#                           GRUPO  Quantidade
# 17  PROCEDIMENTOS LABORATORIAIS         991

# %%
contagem = df[df['GRUPO'] == 'PROCEDIMENTOS LABORATORIAIS'].shape[0]
print(f"Quantidade de procedimentos laboratoriais: {contagem}")
# Out:
# Quantidade de procedimentos laboratoriais: 991

# %%
df2 = df.sort_values(['GRUPO', 'CODIGO'], ascending=[True, True])

# %%
df2.head(8)
# Out:
#           CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 3402  40305279.0  Dosagem de receptor de progesterona ou de estr...     SIM
# 3623  40307840.0      Urease, teste rápido para helicobacter pylori     SIM
# 3983  40312267.0                         Líquido pleural citológico     SIM
# 4670  40403092.0  Determinação de conteúdo de DNA - Citômetro de...     SIM
# 4853  40501116.0                                   Cromatina X ou Y     SIM
# 4855  40501132.0  Cultura de tecido para ensaio enzimático e/ou ...     SIM
# 5065  40601013.0  Procedimento diagnóstico peroperatório sem des...     SIM
# 5066  40601021.0  Procedimento diagnóstico peroperatório - peça ...     SIM
#
#      ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 3402  DETECÇÃO DE RECEPTORES DE SECREÇÃO HORMONAL E/...
# 3623      UREASE, TESTE RÁPIDO PARA HELICOBACTER PYLORI
# 3983  PROCEDIMENTO DIAGNÓSTICO ANATOMOPATOLÓGICO (EM...
# 4670  ANÁLISE DE DNA (CONTEÚDO E PLOIDIA) POR CITOME...
# 4853  COLORAÇÕES ESPECIAIS, QUANDO NECESSÁRIAS AOS P...
# 4855  ANÁLISE DE DNA (CONTEÚDO E PLOIDIA) POR CITOME...
# 5065  PROCEDIMENTO DIAGNÓSTICO ANATOMOPATOLÓGICO POR...
# 5066  PROCEDIMENTO DIAGNÓSTICO ANATOMOPATOLÓGICO EM ...
#
#            SUBGRUPO                                GRUPO  \
# 3402  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 3623  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 3983  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 4670  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 4853  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 4855  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 5065  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
# 5066  PROCEDIMENTOS  ANATOMIA PATOLÓGICA E CITOPATOLOGIA
#
#                                        CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 3402  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  PAC  NaN
# 3623  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  NaN  NaN
# 3983  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS   OD  AMB  HCO  HSO  NaN  NaN
# 4670  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  PAC  NaN
# 4853  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  PAC  NaN
# 4855  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  PAC  NaN
# 5065  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  NaN  NaN
# 5066  PROCEDIMENTOS DIAGNÓSTICOS E TERAPÊUTICOS  NaN  AMB  HCO  HSO  NaN  NaN

# %%
quantidade_sim = df2[df2["ROL_ANS"] == "SIM"].shape[0]
print(f"Quantidade de 'SIM': {quantidade_sim}")
# Out:
# Quantidade de 'SIM': 5251

# %%
quantidade_nao = df2[df2["ROL_ANS"] == "NÃO"].shape[0]
print(f"Quantidade de 'NEGATIVA': {quantidade_nao}")
# Out:
# Quantidade de 'NEGATIVA': 1144

# %%
df.columns
# Out:
# Index(['CODIGO', 'PROCEDIMENTOS', 'ROL_ANS',
#        'ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                           ',
#        'SUBGRUPO', 'GRUPO', 'CAPITULO', 'OD', 'AMB', 'HCO', 'HSO', 'PAC',
#        'D.UT'],
#       dtype='object')

# %%
print(quantidade_nao)
# Out:
# 1144

# %%
# Filtrando o dataframe para manter apenas as linhas onde o valor da coluna 'ROL_ANS' é 'SIM'
df_sim2 = df.where(df['ROL_ANS'] == 'SIM')
print(df_sim2)
# Out:
#           CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0     10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1     10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2     10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3            NaN                                                NaN     NaN
# 4     10101039.0                         Consulta em pronto socorro     SIM
# ...          ...                                                ...     ...
# 6396  87000067.0         Coroa de policarbonato em dente permanente     SIM
# 6397  87000148.0  Estabilização por meio de contenção física e/o...     SIM
# 6398         NaN                                                NaN     NaN
# 6399         NaN                                                NaN     NaN
# 6400         NaN                                                NaN     NaN
#
#      ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                       CONSULTA MÉDICA
# 1      ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2     CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                   NaN
# 4                                       CONSULTA MÉDICA
# ...                                                 ...
# 6396  REABILITAÇÃO COM COROA DE ACETATO, AÇO OU POLI...
# 6397  CONDICIONAMENTO EM ODONTOLOGIA (COM DIRETRIZ D...
# 6398                                                NaN
# 6399                                                NaN
# 6400                                                NaN
#
#                                                SUBGRUPO                 GRUPO  \
# 0     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                   NaN                   NaN
# 4     CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# ...                                                 ...                   ...
# 6396                                               BOCA      CABEÇA E PESCOÇO
# 6397  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 6398                                                NaN                   NaN
# 6399                                                NaN                   NaN
# 6400                                                NaN                   NaN
#
#                                   CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 0                     PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1                     PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2                     PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                                      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                     PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# ...                                    ...  ...  ...  ...  ...  ...  ...
# 6396  PROCEDIMENTOS CIRÚRGICOS E INVASIVOS   OD  NaN  NaN  NaN  NaN  DUT
# 6397                  PROCEDIMENTOS GERAIS   OD  NaN  NaN  NaN  NaN  DUT
# 6398                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6399                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6400                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [6397 rows x 13 columns]

# %%
df_sim2.head(5)
# Out:
#        CODIGO                                      PROCEDIMENTOS ROL_ANS  \
# 0  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 1  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 2  10101012.0  Consulta em consultório (no horário normal ou ...     SIM
# 3         NaN                                                NaN     NaN
# 4  10101039.0                         Consulta em pronto socorro     SIM
#
#   ROL ANS RESOLUÇÃO NORMATIVA Nº 338/2013                                                                                                                                                                                                             \
# 0                                    CONSULTA MÉDICA
# 1   ATIVIDADE EDUCACIONAL PARA PLANEJAMENTO FAMILIAR
# 2  CONSULTA DE ACONSELHAMENTO PARA PLANEJAMENTO F...
# 3                                                NaN
# 4                                    CONSULTA MÉDICA
#
#                                             SUBGRUPO                 GRUPO  \
# 0  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 1  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 2  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
# 3                                                NaN                   NaN
# 4  CONSULTAS, VISITAS HOSPITALARES OU ACOMPANHAME...  PROCEDIMENTOS GERAIS
#
#                CAPITULO   OD  AMB  HCO  HSO  PAC D.UT
# 0  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 1  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 2  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
# 3                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  PROCEDIMENTOS GERAIS  NaN  AMB  NaN  NaN  NaN  NaN
