# %%
#Biblioteca
import pandas as pd

# %%
df = pd.read_csv(r"E:\data-engineering-projects\_datasets\ebola.csv", low_memory=False)
df.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                    object
# Day                      int64
# Cases_Guinea           float64
# Cases_Liberia          float64
# Cases_SierraLeone      float64
# Cases_Nigeria          float64
# Cases_Senegal          float64
# Cases_UnitedStates     float64
# Cases_Spain            float64
# Cases_Mali             float64
# Deaths_Guinea          float64
# Deaths_Liberia         float64
# Deaths_SierraLeone     float64
# Deaths_Nigeria         float64
# Deaths_Senegal         float64
# Deaths_UnitedStates    float64
# Deaths_Spain           float64
# Deaths_Mali            float64
# dtype: object

# %%
df.shape
# Out:
# (122, 18)

# %%
df.describe()
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# count  122.000000     93.000000      83.000000          87.000000
# mean   144.778689    911.064516    2335.337349        2427.367816
# std     89.316460    849.108801    2987.966721        3184.803996
# min      0.000000     49.000000       3.000000           0.000000
# 25%     66.250000    236.000000      25.500000          64.500000
# 50%    150.000000    495.000000     516.000000         783.000000
# 75%    219.500000   1519.000000    4162.500000        3801.000000
# max    289.000000   2776.000000    8166.000000       10030.000000
#
#        Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# count      38.000000          25.00           18.000000         16.0
# mean       16.736842           1.08            3.277778          1.0
# std         5.998577           0.40            1.178511          0.0
# min         0.000000           1.00            1.000000          1.0
# ...

# %%
df.dtypes
# Out:
# Date                    object
# Day                      int64
# Cases_Guinea           float64
# Cases_Liberia          float64
# Cases_SierraLeone      float64
# Cases_Nigeria          float64
# Cases_Senegal          float64
# Cases_UnitedStates     float64
# Cases_Spain            float64
# Cases_Mali             float64
# Deaths_Guinea          float64
# Deaths_Liberia         float64
# Deaths_SierraLeone     float64
# Deaths_Nigeria         float64
# Deaths_Senegal         float64
# Deaths_UnitedStates    float64
# Deaths_Spain           float64
# Deaths_Mali            float64
# dtype: object

# %%
total = df.shape[0]  # Número de linhas do DataFrame
print(f"Total de registros : {total}")
# Out:
# Total de registros : 122

# %%
df.isnull().sum()  # Verifica valores nulos em cada coluna
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %% [markdown]
# ### Total de Valores Nulos

# %%
print(f"Total de valores nulos : {df.isnull().sum().sum()}")  # Total de valores nulos no DataFrame
df.isnull().sum().sum()
df.shape
# Out:
# Total de valores nulos : 1214
# (122, 18)
